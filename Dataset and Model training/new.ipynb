# %%
import pandas as pd

# %%
df = pd.read_excel('10.xlsx')
df1 = pd.read_excel('10.xlsx',sheet_name='Sheet2')
# df.drop(columns=df['Unnamed: 0'],inplace=True)
print(df1.sample(10))

df.isnull().sum()
df.head(5)
# Out:
#            PRN  No of Offers                 Company 1   Salary
# 61  UCS19M1075             1      Celebal Technologies  5.5 LPA
# 19  UCS19M1012             1      Celebal Technologies  5.5 LPA
# 62  UCS19F1008             1  iBrain Decision Software  2.4 LPA
# 89  UCS19M1071             1                JoshMithra      NaN
# 66  UCS19M1081             1               TCS Digital  7.0 LPA
# 22  UCS19M1116             1      Celebal Technologies  5.5 LPA
# 1   UCS19M1005             2      Celebal Technologies  5.5 LPA
# 0   UCS19F1026             1      Celebal Technologies  5.5 LPA
# 48  UCS19M1050             2                      KPIT  4.5 LPA
# 84  UCS19M1043             1             Glatt Systems  4.0 LPA
#           PRN Gender 10th Percentage  Medium of School Education  \
# 0  UCS19M1093   Male             84.6               Semi English
# 1  UCS19M1128   Male             82.2                    English
# 2  UCS19M1102   Male             80.4               Semi English
# ...

# %% [markdown]
# Making the varible simple

# %%
from sklearn.preprocessing import StandardScaler, MinMaxScaler,OrdinalEncoder
oe = OrdinalEncoder()
ordnal_list = ['Gender','HSC / Diploma','Medium of School Education','Name of Board for 12th Exam']
df[ordnal_list]= oe.fit_transform(df[ordnal_list])
df.dropna(how='all',inplace=True)
df.tail(39)

df.isna().sum()
# Out:
# PRN                             0
# Gender                          0
# 10th Percentage                 0
# Medium of School Education      0
# HSC / Diploma                   0
# Name of Board for 12th Exam    20
# 12th Percentage                21
# Semester 1 CGPA                 0
# Semester 2 CGPA                 0
# Semester 3 SGPA                 0
# Semester 4 CGPA                 0
# Semester 5 CGPA                 0
# dtype: int64

# %%
df['12th Percentage'].fillna(value=df['12th Percentage'].mean(),inplace=True)
df.sample(30)
# Out:
#             PRN  Gender 10th Percentage   Medium of School Education  \
# 63   UCS20F2172     0.0            92 .0                         2.0
# 109  UCS19M1078     1.0               70                         0.0
# 146  UCS19M1002     1.0             86.2                         3.0
# 151  UCS19M1043     1.0               83                         3.0
# 33   UCS19M1001     1.0             85.8                         0.0
# 39   UCS19F1072     0.0             86.2                         3.0
# 54   UCS19M1030     1.0             77.2                         0.0
# 138  UCS19M1046     1.0             84.4                         3.0
# 126  UCS19M1053     1.0             90.2                         3.0
# 35   UCS19M1028     1.0             82.2                         2.0
# 27   UCS19M1068     1.0               91                         3.0
# 136  UCS17F2001     0.0             71.6                         3.0
# 156  UCS19F1112     0.0          68.6 .0                         2.0
# ...

# %%
df['Name of Board for 12th Exam'].fillna(value=df['Name of Board for 12th Exam'].mode()[0],inplace=True)

# %%
# Convert 'Diploma' to NaN
df['Semester 1 CGPA'] = df['Semester 1 CGPA'].replace('Diploma', pd.NA)
df['Semester 2 CGPA'] = df['Semester 2 CGPA'].replace('Diploma', pd.NA)

# Convert columns to numeric
df['Semester 1 CGPA'] = pd.to_numeric(df['Semester 1 CGPA'], errors='coerce')
df['Semester 2 CGPA'] = pd.to_numeric(df['Semester 2 CGPA'], errors='coerce')

# Replace NaN with mean
df['Semester 1 CGPA'].fillna(df['Semester 1 CGPA'].mean(), inplace=True)
df['Semester 2 CGPA'].fillna(df['Semester 2 CGPA'].mean(), inplace=True)

# %%
df.isnull().sum()
df.dtypes
# Out:
# PRN                             object
# Gender                         float64
# 10th Percentage                 object
# Medium of School Education     float64
# HSC / Diploma                  float64
# Name of Board for 12th Exam    float64
# 12th Percentage                float64
# Semester 1 CGPA                float64
# Semester 2 CGPA                float64
# Semester 3 SGPA                float64
# Semester 4 CGPA                float64
# Semester 5 CGPA                float64
# dtype: object

# %%
import seaborn as sns
sns.pairplot(df)

# %%
df['Semester 2 CGPA'].unique()
# Out:
# array([8.6       , 8.86      , 7.95      , 8.09      , 9.82      ,
#        7.1       , 8.82      , 7.66      , 8.45      , 9.09      ,
#        8.5       , 7.        , 8.14      , 8.55      , 7.48      ,
#        6.6       , 8.3       , 6.73      , 7.77      , 7.73      ,
#        9.        , 6.08      , 9.3       , 8.02      , 7.6       ,
#        6.22      , 6.09      , 9.14      , 6.25      , 7.09      ,
#        7.98      , 9.18      , 7.01      , 9.32      , 7.5       ,
#        6.56      , 8.91      , 8.01      , 8.9       , 9.4       ,
#        6.06      , 8.36      , 7.9       , 8.27      , 9.55      ,
#        7.79931034, 6.02      , 7.04      , 9.9       , 9.5       ,
#        9.45      , 7.91      , 6.2       , 6.04      , 7.32      ,
#        9.41      , 8.25      , 8.68      , 7.3       , 8.41      ,
#        7.05      , 8.32      , 6.34      , 7.4       , 7.02      ,
#        8.77      , 0.        , 6.44      , 7.2       , 4.8       ,
# ...

# %%
# Replace 0 values with NaN
df['Semester 1 CGPA'].replace(0, pd.NA, inplace=True)
df['Semester 2 CGPA'].replace(0, pd.NA, inplace=True)
df['Semester 5 CGPA'].replace(0, pd.NA, inplace=True)

# Convert columns to numeric



# # Replace NaN with mean

# %%
df['Semester 1 CGPA'] = pd.to_numeric(df['Semester 1 CGPA'], errors='coerce')
df['Semester 2 CGPA'] = pd.to_numeric(df['Semester 2 CGPA'], errors='coerce')
df['Semester 5 CGPA'] = pd.to_numeric(df['Semester 5 CGPA'], errors='coerce')

# %%
df['Semester 1 CGPA'].fillna(df['Semester 1 CGPA'].mean(), inplace=True)
df['Semester 2 CGPA'].fillna(df['Semester 2 CGPA'].mean(), inplace=True)
df['Semester 5 CGPA'].fillna(df['Semester 5 CGPA'].mean(), inplace=True)

# %%
df['Semester 5 CGPA'].unique()
# Out:
# array([8.5       , 8.01090909, 8.1       , 8.08      , 9.55      ,
#        7.7       , 8.86      , 8.4       , 8.66      , 8.03      ,
#        8.3       , 8.05      , 8.        , 7.06      , 7.04      ,
#        9.        , 8.06      , 7.07      , 7.68      , 7.        ,
#        8.7       , 7.09      , 7.8       , 8.02      , 8.23      ,
#        7.08      , 8.8       , 8.6       , 8.9       , 8.09      ,
#        8.07      , 7.02      , 8.45      , 9.2       , 7.9       ,
#        8.26      , 9.4       , 9.01      , 7.03      , 9.14      ,
#        9.11      , 9.02      , 9.5       , 9.3       , 9.18      ,
#        7.42      , 6.44      , 8.01      , 6.08      , 7.2       ,
#        7.05      , 6.7       ])

# %%
df['10th Percentage '].dtype
# df.columns
df['10th Percentage '].replace(0, pd.NA, inplace=True)

# %%
df['10th Percentage '] = pd.to_numeric(df['10th Percentage '], errors='coerce')
df['10th Percentage '].fillna(df['10th Percentage '].mean(), inplace=True)

# %%
df['10th Percentage '].mean()
# Out:
# 84.42301369863014

# %%
df.sample(50)
# Out:
#             PRN  Gender  10th Percentage   Medium of School Education  \
# 63   UCS20F2172     0.0         84.423014                         2.0
# 101  UCS19M1031     1.0         95.200000                         0.0
# 83   UCS19M1096     1.0         80.800000                         0.0
# 86   UCS20F2171     0.0         93.200000                         3.0
# 49   UCS18F2008     0.0         74.100000                         0.0
# 143  UCS19F1024     0.0         77.400000                         3.0
# 14   UCS19M1126     1.0         88.200000                         2.0
# 132  UCS18M2014     1.0         84.423014                         0.0
# 2    UCS19M1102     1.0         80.400000                         3.0
# 46   UCS19M1077     1.0         84.400000                         3.0
# 157  UCS19F1033     0.0         84.600000                         0.0
# 150  UCS19F1036     0.0         84.200000                         3.0
# ...

# %%
import seaborn as sns 
df1['Placed'] = df1['Company 1'].notna().astype(int)
df['Placed'] = df['PRN'].isin(df1['PRN']).astype(int)
df.isna().sum()
df.dtypes
# sns.pairplot(df)
# Out:
# PRN                             object
# Gender                         float64
# 10th Percentage                float64
# Medium of School Education     float64
# HSC / Diploma                  float64
# Name of Board for 12th Exam    float64
# 12th Percentage                float64
# Semester 1 CGPA                float64
# Semester 2 CGPA                float64
# Semester 3 SGPA                float64
# Semester 4 CGPA                float64
# Semester 5 CGPA                float64
# Placed                           int32
# dtype: object

# %%
df.drop(columns=['PRN'], inplace=True)

# %%
from sklearn.preprocessing import StandardScaler, MinMaxScaler,OrdinalEncoder
columns_to_standardize = ['10th Percentage ', '12th Percentage', 'Semester 1 CGPA', 'Semester 2 CGPA', 'Semester 3 SGPA', 'Semester 4 CGPA', 'Semester 5 CGPA']
min =MinMaxScaler()
df[columns_to_standardize] = min.fit_transform(df[columns_to_standardize])

df.head(30)
# Out:
#     Gender  10th Percentage   Medium of School Education  HSC / Diploma  \
# 0      1.0          0.690058                         3.0            1.0
# 1      1.0          0.619883                         0.0            1.0
# 2      1.0          0.567251                         3.0            1.0
# 3      1.0          0.789474                         2.0            1.0
# 4      1.0          0.970760                         0.0            1.0
# 5      1.0          0.555556                         0.0            1.0
# 6      1.0          0.859649                         2.0            1.0
# 7      1.0          0.953216                         2.0            1.0
# 8      1.0          0.684883                         0.0            1.0
# 9      0.0          0.824561                         3.0            1.0
# 10     1.0          0.900585                         2.0            1.0
# 11     1.0          0.549708                         3.0            1.0
# ...

# %%
# Create a DataFrame from the dictionary
# df = pd.DataFrame(data)

# Print the DataFrame
print(df)

# Save the DataFrame to a CSV file
df.to_csv('data.csv', index=False)
# Out:
#      Gender  10th Percentage   Medium of School Education  HSC / Diploma  \
# 0       1.0          0.690058                         3.0            1.0
# 1       1.0          0.619883                         0.0            1.0
# 2       1.0          0.567251                         3.0            1.0
# 3       1.0          0.789474                         2.0            1.0
# 4       1.0          0.970760                         0.0            1.0
# ..      ...               ...                         ...            ...
# 153     1.0          0.549708                         3.0            1.0
# 154     1.0          0.684883                         3.0            1.0
# 155     0.0          0.549708                         3.0            1.0
# 156     0.0          0.684883                         2.0            1.0
# 157     0.0          0.690058                         0.0            1.0
#
#      Name of Board for 12th Exam  12th Percentage  Semester 1 CGPA  \
# ...

# %%
sns.heatmap(df.corr(),annot=True,fmt="0.02f")
# plt.show()
# Out:
# <AxesSubplot:>

# %%
from sklearn.model_selection import train_test_split, cross_val_score
from sklearn.tree import DecisionTreeClassifier
from sklearn.svm import SVC
from sklearn.neighbors import KNeighborsClassifier
from sklearn.naive_bayes import GaussianNB
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import accuracy_score

# Features and target variable
X = df.drop('Placed', axis=1)
y = df['Placed']

# Train-test split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=35)

# Decision Tree
dt_model = DecisionTreeClassifier(random_state=42)
dt_model.fit(X_train, y_train)
dt_accuracy = accuracy_score(y_test, dt_model.predict(X_test))

# SVM
svm_model = SVC(random_state=42,kernel='poly')
svm_model.fit(X_train, y_train)
svm_accuracy = accuracy_score(y_test, svm_model.predict(X_test))

# KNN
knn_model = KNeighborsClassifier()
knn_model.fit(X_train, y_train)
knn_accuracy = accuracy_score(y_test, knn_model.predict(X_test))

# Naive Bayes
nb_model = GaussianNB()
nb_model.fit(X_train, y_train)
nb_accuracy = accuracy_score(y_test, nb_model.predict(X_test))

# Ensemble Learning - Random Forest
rf_model = RandomForestClassifier(random_state=15,n_estimators= 80, criterion="gini",max_features='sqrt')
rf_model.fit(X_train, y_train)
rf_accuracy = accuracy_score(y_test, rf_model.predict(X_test))

# N-fold Cross-Validation
n_fold = 10
dt_cv_accuracy = cross_val_score(dt_model, X, y, cv=n_fold, scoring='accuracy').mean()
svm_cv_accuracy = cross_val_score(svm_model, X, y, cv=n_fold, scoring='accuracy').mean()
knn_cv_accuracy = cross_val_score(knn_model, X, y, cv=n_fold, scoring='accuracy').mean()
nb_cv_accuracy = cross_val_score(nb_model, X, y, cv=n_fold, scoring='accuracy').mean()
rf_cv_accuracy = cross_val_score(rf_model, X, y, cv=n_fold, scoring='accuracy').mean()

print("Decision Tree Accuracy:", dt_accuracy)
print("SVM Accuracy:", svm_accuracy)
print("KNN Accuracy:", knn_accuracy)
print("Naive Bayes Accuracy:", nb_accuracy)
print("Random Forest Accuracy:", rf_accuracy)

print("\nN-fold Cross-Validation Accuracy:")
print("Decision Tree:", dt_cv_accuracy)
print("SVM:", svm_cv_accuracy)
print("KNN:", knn_cv_accuracy)
print("Naive Bayes:", nb_cv_accuracy)
print("Random Forest:", rf_cv_accuracy)
# Out:
# Decision Tree Accuracy: 0.625
# SVM Accuracy: 0.4375
# KNN Accuracy: 0.59375
# Naive Bayes Accuracy: 0.46875
# Random Forest Accuracy: 0.53125
#
# N-fold Cross-Validation Accuracy:
# Decision Tree: 0.5683333333333334
# SVM: 0.6129166666666667
# KNN: 0.6583333333333334
# Naive Bayes: 0.6695833333333334
# Random Forest: 0.6766666666666666

# %%
from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import GridSearchCV

# Define the parameter grid
param_grid = {
    'n_estimators': [50, 100, 200],
    'max_depth': [None, 10, 20],
    'min_samples_split': [2, 5, 10],
    'min_samples_leaf': [1, 2, 4],
    'max_features': ['auto', 'sqrt', 'log2'],
    'bootstrap': [True, False]
}

# Create the Random Forest Classifier
rf_classifier = RandomForestClassifier()

# Perform grid search
grid_search = GridSearchCV(estimator=rf_classifier, param_grid=param_grid, cv=5, scoring='accuracy')
grid_search.fit(X_train, y_train)

# Get the best parameters
best_params = grid_search.best_params_
print("Best parameters:", best_params)
# Out:
# Best parameters: {'bootstrap': True, 'max_depth': 20, 'max_features': 'sqrt', 'min_samples_leaf': 4, 'min_samples_split': 10, 'n_estimators': 50}

# %%
import pandas as pd
import numpy as np

# Define the number of rows in the dataset
num_rows = 1000

# Generate random data with adjusted distributions and patterns
gender = np.random.randint(0, 2, size=num_rows)
tenth_percentage = np.random.uniform(60, 100, size=num_rows)
medium_of_education = np.random.randint(0, 4, size=num_rows)
hsc_or_diploma = np.random.randint(0, 2, size=num_rows)
board_for_12th_exam = np.random.randint(0, 2, size=num_rows)
twelfth_percentage = np.random.uniform(70, 100, size=num_rows)
semester_1_cgpa = np.random.uniform(7, 10, size=num_rows)
semester_2_cgpa = np.random.uniform(7, 10, size=num_rows)
semester_3_sgpa = np.random.uniform(7, 10, size=num_rows)
semester_4_cgpa = np.random.uniform(7, 10, size=num_rows)
semester_5_cgpa = np.random.uniform(7, 10, size=num_rows)

# Introduce patterns for placement based on certain conditions
# For example, students with high percentages in 10th and 12th and good CGPA are more likely to be placed
placed = np.where((tenth_percentage > 80) & (twelfth_percentage > 75) & ((semester_1_cgpa + semester_2_cgpa + semester_3_sgpa + semester_4_cgpa + semester_5_cgpa) / 5 > 7.2), 1, 0)

# Create DataFrame
data = {
    'Gender': gender,
    '10th Percentage': tenth_percentage,
    'Medium of School Education': medium_of_education,
    'HSC / Diploma': hsc_or_diploma,
    'Name of Board for 12th Exam': board_for_12th_exam,
    '12th Percentage': twelfth_percentage,
    'Semester 1 CGPA': semester_1_cgpa,
    'Semester 2 CGPA': semester_2_cgpa,
    'Semester 3 SGPA': semester_3_sgpa,
    'Semester 4 CGPA': semester_4_cgpa,
    'Semester 5 CGPA': semester_5_cgpa,
    'Placed': placed
}

df = pd.DataFrame(data)


# Save DataFrame to CSV
df.to_csv('patterned_generated_dataset.csv', index=False)

# Display DataFrame
df.head(30)
