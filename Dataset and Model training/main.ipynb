# %%
import pandas as pd

# %%
# df = pd.read_excel("2024.xlsx")
# df.shape #680 ,24
df = pd.read_excel('2024.xlsx',sheet_name='Scores, Recommendations', skiprows=2, header=5)
# df.drop(columns=df['Unnamed: 0'],inplace=True)
df1=df.drop(['Unnamed: 0','Employability Index','CoCubesId','Batch'],axis=1)
df1.head(20)
# print(df)
# Out:
# c:\Users\Om Bade\AppData\Local\Programs\Python\Python310\lib\site-packages\openpyxl\packaging\custom.py:212: UserWarning: Unknown type for WorkbookGuid
#   warn(f"Unknown type for {prop.name}")
#                            Name    RollNumber  \
# 0           Tanuja Ramesh Gadhe    UCS20F1132
# 1         Sairaj Pradip Bhakare    UCS20M1022
# 2             Vivek Vijay Kadam    UCS20M1060
# 3            Mayur Kailas Pawar    UCS20M1103
# 4      Pandhare Harshalini Balu    UCS20F1095
# 5          Umesh Krushna Bobade    UIT20M1010
# 6        Atharva Vinod Ghodekar    UIT20M1025
# 7        Pranav Padmakar Thorat    UIT21M2078
# 8              Vaibhav Lokhande    UIT20M1039
# 9          Joshi Pranav Shekhar    UCS20M1057
# 10           Vikas Vijay Bankar    UCS20M1019
# 11     Renuka Rajendra Shirsath  UCS20F201126
# 12           Nisha Sunil Aglave    UCS20F1004
# 13      Akanksha Dwarkanath Hon    UIT21F2077
# 14        Sarthak Laxman Shinde    UIT20M1059
# ...

# %%
# importing packages
import pandas as pd
from pandas_profiling import ProfileReport
# forming ProfileReport and save
# as output.html file
profile = ProfileReport(df)
profile
# Out:
# ---------------------------------------------------------------------------
# PydanticImportError                       Traceback (most recent call last)
# Input In [1], in <cell line: 3>()
#       1 # importing packages
#       2 import pandas as pd
# ----> 3 from pandas_profiling import ProfileReport
#       4 # forming ProfileReport and save
#       5 # as output.html file
#       6 profile = ProfileReport(df)
#
# File c:\Users\Om Bade\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas_profiling\__init__.py:8, in <module>
#       1 """Main module of pandas-profiling.
#       2
#       3 .. include:: ../../README.md
#       4 """
#       6 from warnings import warn
# ----> 8 from pandas_profiling.compare_reports import compare
#       9 from pandas_profiling.controller import pandas_decorator
#      10 from pandas_profiling.profile_report import ProfileReport
#
# ...

# %%
print("THe total shape is ",df.shape)
print("The Columns in the data frame is "df.columns)
df.fillna(value=)
# Out:
# THe total shape is  (673, 24)
# Index(['Unnamed: 0', 'CoCubesId', 'Name', 'RollNumber', 'Branch, Degree',
#        'Batch', 'Score/800', 'Aptitude', 'English', 'Quantitative',
#        'Analytical', 'Domain', 'Computer Fundamental', 'Coding',
#        'Written English', 'Personality', 'Employability Index', 'Analytical.1',
#        'Quantitative.1', 'English.1', 'Domain.1', 'Computer Fundamentals',
#        'Coding.1', 'WET'],
#       dtype='object')

# %%
import seaborn as sns
import matplotlib.pyplot as plt
sns.histplot(x=df['Quantitative.1'] ,color='red')
plt.show()
sns.histplot(x=df['English.1'])
plt.show()
sns.histplot(x=df['Batch'])
plt.show()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Input In [75], in <cell line: 9>()
#       7 sns.histplot(x=df['Batch'])
#       8 plt.show()
# ----> 9 df['Batch'].unique.sum()
#
# AttributeError: 'function' object has no attribute 'sum'

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Check the column names
print(df.columns)

# Strip leading and trailing whitespaces from column names
df.columns = df.columns.str.strip()

# Check again to verify the changes
print(df.columns)

# Plot the histogram
sns.histplot(data=df['Analytical'])
plt.show()
# Out:
# Index(['Unnamed: 13', 'Unnamed: 14', 'Unnamed: 15', 'Unnamed: 16',
#        'Unnamed: 17', 'Unnamed: 18', 'Unnamed: 19', 'Unnamed: 20',
#        'Unnamed: 21', 'Unnamed: 22', 'Unnamed: 23'],
#       dtype='object')
# Index(['Unnamed: 13', 'Unnamed: 14', 'Unnamed: 15', 'Unnamed: 16',
#        'Unnamed: 17', 'Unnamed: 18', 'Unnamed: 19', 'Unnamed: 20',
#        'Unnamed: 21', 'Unnamed: 22', 'Unnamed: 23'],
#       dtype='object')
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File c:\Users\Om Bade\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\core\indexes\base.py:3361, in Index.get_loc(self, key, method, tolerance)
#    3360 try:
# -> 3361     return self._engine.get_loc(casted_key)
#    3362 except KeyError as err:
#
# ...
